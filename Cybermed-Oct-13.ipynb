# %% [markdown]
# # Занятие по кибермедицине, 13 Октября 2016, часть первая.
# Давайте проясним некоторые затруднения, возникшие в прошлый раз.
#
# ## Интерактивная среда
# На всех лаборатрных компьютеров кроме №№ 10, 15 & 16 утстановлен набор инструментов для научных вычислений и визуализации данных Anaconda, который включает в себя интерактивную среду jupyter, в которой и подготовлен и может быть оживлен этот документ. На лабороторные вычислители ничего доустанавливать не надо, а на свои вы можете посавить ту же самую Анаконду.
#
#
# ## Математика
# Я буду рассказывать некоторые математеческие сюжеты, которые можно будет перевести в код и поиграть с ними живьем.
# ## Проекты
# Вы пришли сюда после занятий в Проектном Офисе и Конструкторском Бюро, где вы занимались, как заверяют меня руководители, продумыванием проектов и составлением ТЗ. Я вас постоянно думать, как из кусочков программирования и математики, которые мы тут разбираем, можно сделать части ваших проектов.
# ## Как учиться программированию
# Надо понимать, что происходит, и решать задачи. Про то, что происходит, мы будем с вами разговаривать на занятиях и в чатике, а задачи берутся во-первых из ваших проектов, а во-вторых из учебников и задачников. Поскольку мы все движемся с разных мест и с разной скоростью, то это нормально часть занятия сидеть и решать свои задачки, а часть — обсуждать их в группе. Как коллеги тут подсказывают, есть хорошие русскоязычные ресурсы pythontutor.ru. kpolyakov.spb.ru, кроме того, азы языка Python последовательно излагаются в LearnPythonTheHardWay.org/book/ex0.html, и есть сайты с задачками, которые можно решать на любом языке:
# - codewars.com
# - exercism.io
# - hackerrank.com
# - codeforces.ru
